# %%
# Instalando as libs necessárias.
# !pip install fuzzywuzzy
# Out:
# Requirement already satisfied: fuzzywuzzy in /usr/local/lib/python3.6/dist-packages (0.17.0)

# %%
# Importando os módulos.
import pandas as pd
import numpy as np
import pandas_profiling
import nltk
import warnings
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
warnings.filterwarnings("ignore")
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /usr/local/lib/python3.6/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Dataset principal.
df = pd.read_csv("drive/My Drive/Colab Notebooks/NLP/wiki_movie_plots_deduped.csv")

# %%
# Importando as colunas a serem utilizadas.
df = pd.DataFrame(df,columns=["Title","Genre","Plot"])

# %%
# Vamos utilizar um outro Dataset com os genêros já padronizados.
df_2 = pd.read_csv("drive/My Drive/Colab Notebooks/NLP/movie_metadata.csv")

# %%
# Queremos somente a coluna com a descrição dos genêros.
df_2 = pd.DataFrame(df_2,columns=["genres"])

# %% [markdown]
# Visualizando o primeiro DataFrame.

# %%
df.head(20)
# Out:
#                                                 Title  ...                                               Plot
# 0                              Kansas Saloon Smashers  ...  A bartender is working at a saloon, serving dr...
# 1                       Love by the Light of the Moon  ...  The moon, painted with a smiling face hangs ov...
# 2                             The Martyred Presidents  ...  The film, just over a minute long, is composed...
# 3                    Terrible Teddy, the Grizzly King  ...  Lasting just 61 seconds and consisting of two ...
# 4                              Jack and the Beanstalk  ...  The earliest known adaptation of the classic f...
# 5                                 Alice in Wonderland  ...  Alice follows a large white rabbit down a "Rab...
# 6                             The Great Train Robbery  ...  The film opens with two bandits breaking into ...
# 7                                     The Suburbanite  ...  The film is about a family who move to the sub...
# 8                            The Little Train Robbery  ...  The opening scene shows the interior of the ro...
# 9                          The Night Before Christmas  ...  Scenes are introduced using lines of the poem....
# 10                           Dream of a Rarebit Fiend  ...  The Rarebit Fiend gorges on Welsh rarebit at a...
# 11  From Leadville to Aspen: A Hold-Up in the Rockies  ...  The film features a train traveling through th...
# 12                                Kathleen Mavourneen  ...  Irish villager Kathleen is a tenant of Captain...
# 13                                       Daniel Boone  ...  Boone's daughter befriends an Indian maiden as...
# 14                    How Brown Saw the Baseball Game  ...  Before heading out to a baseball game at a nea...
# 15                                       Laughing Gas  ...  The plot is that of a black woman going to the...
# 16                           The Adventures of Dollie  ...  On a beautiful summer day a father and mother ...
# 17                                    The Black Viper  ...  A thug accosts a girl as she leaves her workpl...
# 18                             A Calamitous Elopement  ...  A young couple decides to elope after being ca...
# 19                               The Call of the Wild  ...  A white girl (Florence Lawrence) rejects a pro...
#
# [20 rows x 3 columns]

# %% [markdown]
# Visualizando o segundo DataFrame.

# %%
df_2.head(20)
# Out:
#                                                genres
# 0                     Action|Adventure|Fantasy|Sci-Fi
# 1                            Action|Adventure|Fantasy
# 2                           Action|Adventure|Thriller
# 3                                     Action|Thriller
# 4                                         Documentary
# 5                             Action|Adventure|Sci-Fi
# 6                            Action|Adventure|Romance
# 7   Adventure|Animation|Comedy|Family|Fantasy|Musi...
# 8                             Action|Adventure|Sci-Fi
# 9                    Adventure|Family|Fantasy|Mystery
# 10                            Action|Adventure|Sci-Fi
# 11                            Action|Adventure|Sci-Fi
# 12                                   Action|Adventure
# 13                           Action|Adventure|Fantasy
# 14                           Action|Adventure|Western
# 15                    Action|Adventure|Fantasy|Sci-Fi
# 16                    Action|Adventure|Family|Fantasy
# 17                            Action|Adventure|Sci-Fi
# 18                           Action|Adventure|Fantasy
# 19      Action|Adventure|Comedy|Family|Fantasy|Sci-Fi

# %% [markdown]
# * A coluna "Genre" do primeiro DataFrame é onde se encontra os dados com problemas de escrita.
# * Na coluna "genres" os dados já estão limpos e devidamente padronizados.

# %%
df_ = df_2.drop_duplicates()

# %% [markdown]
# Vamos dar uma olhada na quantidade de valores únicos que as essas colunas possuem.

# %%
 print(df["Genre"].unique().shape[0])
# Out:
# 2265

# %%
 print(df_2["genres"].unique().shape[0])
# Out:
# 914

# %% [markdown]
# Visualizando alguns dados.

# %%
df["Genre"].unique().tolist()[:20]
# Out:
# ['unknown',
#  'western',
#  'comedy',
#  'short',
#  'short action/crime western',
#  'short film',
#  'biographical',
#  'drama',
#  'adventure',
#  'short fantasy',
#  'silent sports',
#  'horror',
#  'crime',
#  'drama, horror',
#  'historical drama',
#  'fantasy drama',
#  'biographical drama',
#  'documentary drama',
#  'fantasy',
#  'adventure serial']

# %%
df_2["genres"].unique().tolist()[:20]
# Out:
# ['Action|Adventure|Fantasy|Sci-Fi',
#  'Action|Adventure|Fantasy',
#  'Action|Adventure|Thriller',
#  'Action|Thriller',
#  'Documentary',
#  'Action|Adventure|Sci-Fi',
#  'Action|Adventure|Romance',
#  'Adventure|Animation|Comedy|Family|Fantasy|Musical|Romance',
#  'Adventure|Family|Fantasy|Mystery',
#  'Action|Adventure',
#  'Action|Adventure|Western',
#  'Action|Adventure|Family|Fantasy',
#  'Action|Adventure|Comedy|Family|Fantasy|Sci-Fi',
#  'Adventure|Fantasy',
#  'Action|Adventure|Drama|History',
#  'Adventure|Family|Fantasy',
#  'Action|Adventure|Drama|Romance',
#  'Drama|Romance',
#  'Action|Adventure|Sci-Fi|Thriller',
#  'Action|Adventure|Fantasy|Romance']

# %% [markdown]
# Nossa coluna "Genre" possui dados que estão separados por vírgula, alguns por traços, ou seja, não existe nenhum padrão. Podemos resolver isso facilmente removendo todos os caracteres que são estranhos.

# %%
df["Genre"] = df["Genre"].str.replace('[^A-Za-z]+', ' ')

# %% [markdown]
# Temos também valores que são indefinidos, nesse caso vamos transformar esse valores em branco.

# %%
df["Genre"] = df["Genre"].str.replace('unknown', ' ')

# %% [markdown]
# Vamos verificar como ficou nosso dataset depois dessas transformações.

# %%
df["Genre"].unique().tolist()[:20]
# Out:
# [' ',
#  'western',
#  'comedy',
#  'short',
#  'short action crime western',
#  'short film',
#  'biographical',
#  'drama',
#  'adventure',
#  'short fantasy',
#  'silent sports',
#  'horror',
#  'crime',
#  'drama horror',
#  'historical drama',
#  'fantasy drama',
#  'biographical drama',
#  'documentary drama',
#  'fantasy',
#  'adventure serial']

# %% [markdown]
# Agora vamos criar uma função para aplicar a biblioteca fuzzywuzzy.
# Esta função utiliza a biblioteca fuzzywuzzy para comparar cada genêro com
# uma String que está correta, caso haja algum problema de grafia a string é substituída pela forma correta.

# %%
def replace_matches_in_column(data, column, string_match, min_ratio, only_test=False):

    # lista de strings únicas.
    strings = data[column].unique()

    # Definindo 10 como o número limite de strings mais correspondentes.
    matches = process.extract(string_match, strings,
                                         limit=10,
                                         scorer=fuzz.token_sort_ratio)

    # Obtendo as correspondencias que são maiores que o min_ratio.
    close_matches = [matches[0] for matches in matches if matches[1] >= min_ratio]
    if len(close_matches) > 0:
        print(string_match, ':', close_matches)

    # Obtendo as linhas que não correspondem ao limite definido.
    if not(only_test):
        rows_with_matches = data[column].isin(close_matches)

        # Substituindo todos os valores correspondentes pelo valor de entrada.
        # Os valores que não são correspondentes irão permanecer os mesmos.
        data.loc[rows_with_matches, column] = string_match

# %%
# Eu utilizei uma taxa de semelhança  de 80%.
for marca in df_2['genres']:
     replace_matches_in_column(data=df, column="Genre", 
                             string_match=marca, min_ratio=80)
# Out:
# Action|Adventure|Fantasy|Sci-Fi : ['action adventure fantasy sci fi', 'action adventure science fantasy', 'action adventure fantasy', 'fantasy action adventure', 'sci fi adventure drama action', 'superhero action adventure fantasy sci fi', 'action adventure sci fi', 'sci fi action adventure', 'action sci fi adventure', 'action adventure fantasy horror']
# Action|Adventure|Fantasy : ['action adventure drama fantasy', 'drama action fantasy adventure', 'Action|Adventure|Fantasy|Sci-Fi', 'action adventure fantasy family', 'action adventure fantasy comedy', 'action fantasy adventure comedy', 'action adventure family', 'fantasy adventure', 'adventure fantasy', 'action adventure drama']
# Action|Adventure|Thriller : ['action adventure thriller', 'action adventure thriller spy', 'action thriller adventure drama', 'action crime adventure', 'action adventure crime', 'adventure thriller', 'thriller adventure', 'action adventure horror', 'action adventure western', 'anime action adventure']
# Action|Thriller : ['action thriller', 'thriller action', 'action thriller ', 'drama action thriller', 'action drama thriller', 'action crime thriller', 'thriller action drama', 'action horror thriller', 'thriller sci fi action', 'action sci fi thriller']
# Documentary : ['documentary', 'mockumentary', 'war documentary', 'documentary film']
# Action|Adventure|Sci-Fi : ['action adventure crime sci fi', 'action adventure horror sci fi', 'action adventure epic', 'action adventure science fiction', 'science fiction action adventure', 'action adventure', 'adventure action', 'Action|Adventure|Fantasy', 'action adventure kung fu']
# Action|Adventure|Romance : ['action adventure romance', 'drama action adventure', 'action drama adventure', 'action adventure family romance', 'action adventure comedy', 'comedy action adventure', 'adventure action comedy', 'adventure romance', 'romance adventure', 'costume action adventure']
# Adventure|Animation|Comedy|Family|Fantasy|Musical|Romance : ['animation adventure comedy family fantasy musical']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Sci-Fi']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Sci-Fi']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Sci-Fi']
# Action|Adventure : ['action war adventure', 'Action|Adventure|Sci-Fi', 'Action|Adventure|Romance']
# Action|Adventure|Fantasy : ['Action|Adventure', 'action animation adventure']
# Action|Adventure|Western : ['Action|Adventure|Thriller', 'action adventure suspense', 'action adventure superhero', 'superhero action adventure', 'comedy action mystery adventure']
# Action|Adventure|Fantasy|Sci-Fi : ['Action|Adventure|Fantasy', 'action fantasy adventure horror sci fi western', 'action fantasy sci fi']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Fantasy|Sci-Fi']
# Action|Adventure|Fantasy : ['Action|Adventure|Sci-Fi']
# Action|Adventure|Comedy|Family|Fantasy|Sci-Fi : ['superhero action adventure fantasy sci fi comedy']
# Adventure|Fantasy : ['adventure epic fantasy ', 'fantasy adventure kids', 'Action|Adventure|Fantasy', 'adventure comedy fantasy', 'horror fantasy adventure', 'fantasy comedy adventure', 'comedy fantasy adventure', 'fantasy adventure comedy']
# Action|Adventure|Fantasy : ['Adventure|Fantasy']
# Action|Adventure|Drama|History : ['adventure drama history', 'action adventure superhero drama', 'action adventure drama superhero']
# Adventure|Fantasy : ['Action|Adventure|Fantasy']
# Adventure|Family|Fantasy : ['Adventure|Fantasy', 'animation fantasy adventure', 'adventure family', 'family adventure', 'adventure animated fantasy']
# Action|Adventure|Drama|Romance : ['action adventure drama romance family', 'action crime drama romance', 'action drama romance crime', 'adventure romantic drama', 'Action|Adventure|Drama|History', 'action romance drama', 'drama action romance', 'drama romance action', 'romance drama action', 'romance action drama']
# Drama|Romance : ['drama romance', 'romance drama', 'drama romance ', 'romance drama ', 'romantic drama', 'romance melodrama', 'romance drama war', 'dramedy romance', 'romance dramedy', 'romanctic drama']
# Action|Adventure|Sci-Fi|Thriller : ['sci fi action thriller']
# Action|Adventure|Sci-Fi|Thriller : ['Action|Adventure|Sci-Fi|Thriller']
# Action|Adventure|Thriller : ['Action|Adventure|Sci-Fi|Thriller', 'Action|Adventure|Western']
# Action|Adventure|Fantasy|Romance : ['Action|Adventure|Drama|Romance', 'fantasy romance action', 'action romance fantasy', 'adventure romance fantasy film', 'action drama fantasy romance']
# Adventure|Family|Fantasy : ['Adventure|Family|Fantasy']
# Adventure|Animation|Comedy|Family|Fantasy : ['adventure animated family fantasy comedy', 'animation fantasy comedy adventure', 'animation adventure comedy family', 'comedy animation family adventure', 'animation comedy fantasy family', 'Adventure|Animation|Comedy|Family|Fantasy|Musical|Romance', 'animation family drama adventure comedy']
# Adventure|Family|Fantasy : ['Adventure|Family|Fantasy']
# Action|Adventure|Fantasy|Sci-Fi : ['Action|Adventure|Fantasy|Romance', 'Action|Adventure|Comedy|Family|Fantasy|Sci-Fi']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Fantasy|Sci-Fi']
# Adventure|Animation|Comedy|Family|Sport : ['Adventure|Animation|Comedy|Family|Fantasy', 'animation comedy adventure', 'animation adventure comedy', 'animation family adventure', 'comedy animation adventure']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Sci-Fi']
# Adventure|Animation|Comedy|Family|Fantasy : ['Adventure|Animation|Comedy|Family|Sport']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Sci-Fi']
# Action|Crime|Thriller : ['action crime ttriller', 'action comedy thriller', 'action crime thriller drama', 'action crime drama thriller', 'action crime drama thriller ', 'action thriller comedy', 'action crime romance thriller', 'action romance thriller crime', 'romcom action thriller', 'Action|Thriller']
# Action|Adventure|Horror|Sci-Fi|Thriller : ['action thriller sci fi horror']
# Action|Adventure|Fantasy|Sci-Fi|Thriller : ['Action|Adventure|Horror|Sci-Fi|Thriller']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Sci-Fi']
# Adventure|Fantasy : ['Adventure|Family|Fantasy']
# Drama|Romance : ['Drama|Romance', 'romance film drama', 'dance drama romance', 'music drama romance', 'romance drama short', 'drama music romance', 'romance crime drama', 'crime drama romance', 'drama romance crime']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Sci-Fi']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Sci-Fi']
# Action|Adventure|Fantasy : ['Adventure|Fantasy', 'Action|Adventure|Sci-Fi']
# Adventure|Animation|Comedy|Family|Fantasy : ['Adventure|Animation|Comedy|Family|Fantasy']
# Adventure|Animation|Comedy|Family|Fantasy : ['Adventure|Animation|Comedy|Family|Fantasy']
# Action|Adventure|Sci-Fi|Thriller : ['Action|Adventure|Fantasy|Sci-Fi|Thriller', 'Action|Adventure|Thriller']
# Adventure|Animation|Family|Sci-Fi : ['animation adventure sci fi']
# Action|Comedy|Crime|Thriller : ['Action|Crime|Thriller', 'comedy action mystery crime', 'comedy action crime', 'action comedy crime', 'action crime comedy', 'action comedy crime romance ']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Sci-Fi|Thriller', 'Action|Adventure|Fantasy']
# Animation|Drama|Family|Fantasy : ['drama animation fantasy', 'animated family fantasy', 'family animated fantasy']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Sci-Fi']
# Action|Adventure|Drama|Romance : ['action drama romance', 'action drama romance ']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Sci-Fi']
# Action|Crime|Drama|Thriller : ['action thriller drama mystery crime', 'drama action crime thriller romance ', 'crime thriller drama', 'comedy drama crime thriller', 'crime drama thriller', 'comedy crime drama thriller', 'drama thriller crime', 'drama crime thriller', 'action crime drama horror', 'drama crime thriller sci fi action spy']
# Adventure|Animation|Comedy|Family : ['Adventure|Animation|Comedy|Family|Fantasy', 'animation action comedy family', 'animation comedy family']
# Action|Adventure|Animation|Comedy|Family|Sci-Fi : ['Adventure|Animation|Comedy|Family', 'Adventure|Animation|Family|Sci-Fi', 'animation comedy adventure action', 'action adventure animated family']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Sci-Fi']
# Adventure|Drama|Family|Mystery : ['adventure family drama', 'adventure drama film']
# Action|Adventure|Comedy|Sci-Fi : ['Action|Adventure|Sci-Fi', 'action adventure superhero comedy sci fi', 'comedy action sci fi animation', 'action adventure comedy crime drama']
# Comedy|Family|Fantasy : ['comedy drama fantasy', 'fantasy drama comedy', 'comedy drama fantasy ', 'comedy fantasy drama', 'fantasy family', 'comedy fantasy', 'fantasy comedy', 'family fantasy', 'comedy familya']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Comedy|Sci-Fi']
# Action|Adventure|Sci-Fi|Thriller : ['Action|Adventure|Sci-Fi']
# Action|Adventure|Sci-Fi|Thriller : ['Action|Adventure|Sci-Fi|Thriller']
# Adventure|Drama|Family|Fantasy : ['Adventure|Drama|Family|Mystery', 'Animation|Drama|Family|Fantasy']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Sci-Fi|Thriller']
# Action|Adventure|Drama|Fantasy : ['Action|Adventure|Drama|Romance', 'fantasy action drama adventure mystery spy', 'superhero action adventure fantasy drama war', 'action drama fantasy', 'drama action fantasy', 'action drama family crime adventure']
# Action|Adventure|Drama|Sci-Fi : ['Action|Adventure|Sci-Fi', 'drama sci fi adventure', 'Action|Adventure|Drama|Fantasy', 'action adventure drama musical family']
# Action|Adventure|Romance|Sci-Fi : ['sci fi adventure romance']
# Action|Adventure|Drama|Fantasy : ['Action|Adventure|Drama|Sci-Fi']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Romance|Sci-Fi']
# Adventure|Animation|Comedy|Family|Fantasy : ['Action|Adventure|Animation|Comedy|Family|Sci-Fi']
# Adventure|Animation|Comedy|Family|Sci-Fi : ['Adventure|Animation|Comedy|Family|Fantasy']
# Adventure|Animation|Family|Fantasy : ['Adventure|Drama|Family|Fantasy']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Sci-Fi']
# Adventure|Animation|Family|Fantasy : ['Adventure|Animation|Family|Fantasy']
# Action|Sci-Fi : ['sci fi action', 'action sci fi', 'sci fi action spy', 'action drama sci fi', 'action sci fi mecha']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Sci-Fi']
# Adventure|Drama|Sci-Fi : ['adventure drama epic', 'drama adventure', 'adventure drama', 'adventure drama ', 'drama mecha sci fi adventure spy', 'adventure children s drama sci fi']
# Action|Adventure|Sci-Fi|Thriller : ['Action|Adventure|Sci-Fi']
# Action|Adventure|Drama|Horror|Sci-Fi : ['horror drama action sci fi']
# Action|Crime|Thriller : ['Action|Crime|Drama|Thriller', 'Action|Comedy|Crime|Thriller', 'adult crime thriller', 'thriller action romance', 'romance action thriller', 'action thriller romance', 'action romance thriller', 'crime thriller', 'science fiction thriller', 'thriller crime']
# Drama|Fantasy|Romance : ['fantasy romance drama', 'romantic fantasy drama', 'drama fantasy horror romance', 'fantasy drama romance sci fi', 'fantasy romance', 'romance fantasy', 'drama romance family', 'family drama romance', 'family romance drama', 'romance family drama']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Sci-Fi|Thriller']
# Adventure|Sci-Fi : ['Adventure|Drama|Sci-Fi', 'Action|Adventure|Sci-Fi', 'adventure film']
# Action|Adventure|Family|Fantasy : ['Action|Adventure|Drama|Fantasy']
# Action|Adventure|Drama|Thriller : ['drama adventure thriller']
# Adventure|Family|Fantasy : ['Action|Adventure|Family|Fantasy', 'Adventure|Animation|Family|Fantasy']
# Adventure|Animation|Comedy|Family|Fantasy : ['Adventure|Animation|Comedy|Family|Sci-Fi']
# Action|Adventure|Sci-Fi : ['Adventure|Sci-Fi']
# Adventure|Family|Fantasy : ['Adventure|Family|Fantasy']
# Action|Drama|History|Romance|War : ['drama war romance action', 'war drama action romance']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Sci-Fi']
# Adventure|Family|Fantasy|Mystery : ['Adventure|Family|Fantasy']
# Adventure|Family|Fantasy|Mystery : ['Adventure|Family|Fantasy|Mystery']
# Action|Drama : ['drama action', 'action drama', 'action drama war', 'drama action war', 'action drama epic ', 'action drama film', 'animation drama', 'crime drama action', 'action crime drama', 'drama action crime']
# Drama|Horror|Sci-Fi : ['horror sci fi drama', 'horror sci fi', 'sci fi horror']
# Adventure|Comedy|Family|Fantasy : ['Adventure|Animation|Comedy|Family|Fantasy', 'comedy fantasy adventure costume', 'Comedy|Family|Fantasy']
# Animation|Comedy|Family|Fantasy : ['comedy animation fantasy', 'Adventure|Comedy|Family|Fantasy']
# Action|Adventure : ['Action|Adventure|Sci-Fi']
# Adventure|Comedy|Family|Fantasy : ['Animation|Comedy|Family|Fantasy']
# Action|Sci-Fi : ['Action|Sci-Fi']
# Action|Sci-Fi : ['Action|Sci-Fi']
# Action|Adventure|Fantasy : ['Action|Adventure']
# Action|Adventure|Sci-Fi|Thriller : ['Action|Adventure|Drama|Thriller']
# Mystery|Thriller : ['mystery thriller', 'thriller mystery', 'thriller mystery ', 'thriller drama mystery', 'drama mystery thriller', 'drama mystery thriller ', 'mystery thriller drama', 'horror mystery thriller', 'mystery thriller horror', 'action mystery thriller']
# Action|Adventure|Fantasy : ['Action|Adventure|Fantasy']
# Adventure|Animation|Comedy|Drama|Family : ['adventure comedy drama family']
# Action|Adventure|Fantasy : ['Action|Adventure|Fantasy']
# Comedy|Fantasy|Horror : ['socio fantasy comedy', 'horror fantasy', 'fantasy horror', 'horror drama comedy', 'comedy drama horror']
# Action|Adventure|Thriller : ['Action|Adventure|Sci-Fi|Thriller']
# Drama|Fantasy|Horror|Thriller : ['drama horror thriller film', 'horror thriller drama', 'drama horror thriller', 'horror fantasy drama']
# Adventure|Animation|Comedy|Family : ['Adventure|Animation|Comedy|Drama|Family']
# Action|Adventure|Animation|Comedy|Family : ['Adventure|Animation|Comedy|Family']
# Action|Adventure|Family|Fantasy : ['Action|Adventure|Fantasy']
# Action|Adventure|Thriller : ['Action|Adventure|Thriller']
# Action|Drama|Thriller : ['Action|Crime|Thriller', 'action drama horror thriller', 'action drama bio pic thriller', 'action drama romance thriller ', 'action thriller fantasy', 'comedy drama thriller', 'drama thriller', 'thriller drama', 'action drama horror', 'drama thriller ']
# Action|Adventure|Animation|Comedy|Family|Sci-Fi : ['Action|Adventure|Animation|Comedy|Family']
# Adventure|Animation|Comedy|Family : ['Action|Adventure|Animation|Comedy|Family|Sci-Fi']
# Adventure|Family|Fantasy : ['Action|Adventure|Family|Fantasy', 'Adventure|Comedy|Family|Fantasy', 'Adventure|Family|Fantasy|Mystery']
# Adventure|Animation|Comedy|Family|Sci-Fi : ['Adventure|Animation|Comedy|Family']
# Adventure : ['adventure', 'adventure ', 'adventures']
# Adventure|Animation|Comedy|Family : ['Adventure|Animation|Comedy|Family|Sci-Fi']
# Action|Adventure|Thriller : ['Action|Adventure|Thriller']
# Action|Comedy|Fantasy|Sci-Fi : ['comedy action fantasy', 'action comedy fantasy', 'fantasy comedy action', 'drama action sci fi comedy']
# Action|Adventure|Sci-Fi|Thriller : ['Action|Adventure|Thriller']
# Action|Adventure|Animation|Comedy|Family : ['Adventure|Animation|Comedy|Family']
# Action|Adventure|Thriller : ['Action|Adventure|Sci-Fi|Thriller']
# Adventure|Animation|Family|Fantasy : ['Adventure|Family|Fantasy']
# Comedy|Crime : ['crime comedy', 'comedy crime', 'crime dark comedy', 'comedy drama crime', 'crime drama comedy', 'crime comedy drama ', 'comedy crime drama']
# Action|Drama|History|War : ['Action|Drama|History|Romance|War', 'action drama historical', 'historical drama action', 'historical action drama', 'drama history war', 'drama war history', 'action history war costume']
# Action|Adventure|Drama : ['action crime drama adventure', 'action drama adventure crime']
# Action|Adventure|Animation|Comedy|Family|Fantasy : ['Action|Adventure|Animation|Comedy|Family', 'Adventure|Animation|Family|Fantasy']
# Action|Adventure|Fantasy : ['Action|Adventure|Drama']
# Action|Adventure|Sci-Fi|Thriller : ['Action|Adventure|Thriller']
# Action|Drama|Mystery|Sci-Fi : ['drama mystery action']
# Action|Crime|Thriller : ['Action|Drama|Thriller', 'action crime horror', 'crime thriller ']
# Action|Sci-Fi : ['Action|Sci-Fi']
# Action|Adventure|Sci-Fi|Thriller : ['Action|Adventure|Sci-Fi|Thriller']
# Action|Adventure|Comedy|Thriller : ['Action|Adventure|Sci-Fi|Thriller']
# Action|Adventure|Animation|Fantasy|Romance|Sci-Fi : ['romance animation fantasy adventure']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Fantasy']
# Action|Adventure|Thriller : ['Action|Adventure|Comedy|Thriller']
# Action|Adventure|Drama|History|War : ['Action|Drama|History|War']
# Adventure|Drama|Fantasy|Romance : ['fantasy adventure musical drama romance', 'Drama|Fantasy|Romance']
# Animation|Comedy|Family|Musical : ['animation musical comedy', 'sci fi animation comedy']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Sci-Fi']
# Action|Crime|Drama|Mystery|Thriller : ['crime comedy drama mystery thriller', 'action drama mystery romance thriller ']
# Adventure|Drama|Thriller|Western : ['adventure drama western']
# Adventure|Animation|Comedy|Family|Sport : ['Action|Adventure|Animation|Comedy|Family|Fantasy']
# Adventure|Animation|Comedy|Family|Western : ['Adventure|Animation|Comedy|Family|Sport']
# Adventure|Animation|Comedy|Family : ['Adventure|Animation|Comedy|Family|Western']
# Action|Mystery|Thriller : ['mystery thriller comedy', 'thriller comedy mystery', 'Mystery|Thriller', 'Action|Crime|Thriller']
# Action|Adventure|Animation|Comedy|Family : ['Adventure|Animation|Comedy|Family']
# Action|Adventure|Comedy|Sci-Fi : ['Action|Adventure|Sci-Fi']
# Adventure|Drama|Fantasy|Romance : ['Adventure|Drama|Fantasy|Romance']
# Action|Adventure|Animation|Comedy|Family|Fantasy : ['Action|Adventure|Animation|Comedy|Family']
# Action|Crime|Mystery|Thriller : ['Action|Crime|Drama|Mystery|Thriller', 'Action|Mystery|Thriller', 'action mystery crime']
# Adventure|Drama|Romance|War : ['adventure crime romance']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Comedy|Sci-Fi']
# Action|Fantasy : ['action fantasy', 'fantasy action', 'animation fantasy']
# Action|Comedy|Fantasy : ['action fantasy costume', 'fantasy and comedy', 'Action|Comedy|Fantasy|Sci-Fi', 'spy action comedy', 'action comedy family', 'comedy action animation fantasy', 'Action|Fantasy', 'action comedy drama', 'comedy action drama', 'drama comedy action']
# Action|Adventure|Drama|Horror|Sci-Fi : ['Action|Adventure|Drama|Horror|Sci-Fi']
# Action|Adventure|Fantasy : ['Action|Adventure|Sci-Fi']
# Fantasy : ['fantasy']
# Mystery|Thriller : ['thriller mystery romance']
# Adventure|Animation|Comedy|Family|Musical : ['Animation|Comedy|Family|Musical']
# Action|Crime|Thriller : ['Action|Crime|Mystery|Thriller']
# Action|Adventure|Crime|Mystery|Thriller : ['adventure mystery thriller']
# Action|Adventure|Fantasy : ['Action|Adventure|Fantasy']
# Action|Sci-Fi : ['Action|Sci-Fi']
# Action|Adventure|History : ['Action|Adventure|Drama|History|War', 'Action|Adventure|Thriller']
# Action : ['action', 'action ']
# Action|Adventure|Sci-Fi|Thriller : ['Action|Adventure|Crime|Mystery|Thriller']
# Action|Adventure|Thriller : ['Action|Adventure|Sci-Fi|Thriller']
# Action|Adventure|Drama|Thriller : ['Action|Adventure|Thriller']
# Action|Adventure|Sci-Fi|Thriller : ['Action|Adventure|Drama|Thriller']
# Adventure|Drama|Fantasy : ['Adventure|Drama|Fantasy|Romance']
# Action|Fantasy|Thriller : ['fantasy thriller', 'thriller fantasy']
# Action|Thriller : ['Action|Crime|Thriller', 'satire thriller']
# Adventure|Mystery|Sci-Fi : ['adventure mystery', 'mystery adventure']
# Adventure|Animation|Comedy|Family|Fantasy : ['Action|Adventure|Animation|Comedy|Family|Fantasy', 'Adventure|Animation|Comedy|Family|Musical']
# Action|Drama|Sci-Fi|Thriller : ['sci fi drama thriller', 'thriller drama sci fi', 'Action|Adventure|Sci-Fi|Thriller']
# Action|Adventure|Sci-Fi|Thriller : ['Action|Drama|Sci-Fi|Thriller']
# Action|Crime|Sci-Fi|Thriller : ['Action|Adventure|Sci-Fi|Thriller']
# Action|Family|Sport : ['action family']
# Comedy|Drama|Romance : ['comedy drama romance', 'romance comedy drama', 'drama comedy romance', 'comedy romance drama', 'romance drama comedy ', 'romance drama comedy', 'comedy drama romance ', 'romantic comedy drama', 'drama romantic comedy', 'teen romantic comedy drama']
# Action|Comedy|Romance : ['action comedy romance', 'action romance comedy', 'romance action comedy', 'action romantic comedy', 'teen romance comedy action', 'action crime romance', 'action comedy drama romance', 'action romance comedy drama', 'comedy drama action', 'drama action comedy']
# Action|Adventure|Mystery|Sci-Fi : ['Adventure|Mystery|Sci-Fi', 'Action|Adventure|History']
# Action|Adventure|Fantasy|Sci-Fi : ['Action|Adventure|Fantasy']
# Action|Adventure|Fantasy|Sci-Fi : ['Action|Adventure|Fantasy|Sci-Fi']
# Adventure|Animation|Comedy|Family|Fantasy : ['Adventure|Animation|Comedy|Family|Fantasy']
# Action|Adventure|Sci-Fi|Thriller : ['Action|Crime|Sci-Fi|Thriller']
# Action|Adventure|Fantasy|Sci-Fi : ['Action|Adventure|Fantasy|Sci-Fi']
# Adventure|Animation|Comedy|Family|Fantasy : ['Adventure|Animation|Comedy|Family|Fantasy']
# Adventure|Comedy|Family|Fantasy : ['Adventure|Animation|Comedy|Family|Fantasy']
# Action|Drama|War : ['Action|Drama', 'drama war comedy action', 'action drama family', 'drama family action', 'drama social action']
# Action|Adventure|Drama|Fantasy : ['Adventure|Drama|Fantasy']
# Action|Adventure|Comedy|Sci-Fi : ['Action|Adventure|Fantasy|Sci-Fi']
# Action|Adventure|Thriller : ['Action|Adventure|Sci-Fi|Thriller']
# Action|Adventure|Comedy|Sci-Fi : ['Action|Adventure|Comedy|Sci-Fi']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Comedy|Sci-Fi', 'Action|Adventure|Mystery|Sci-Fi']
# Action|Adventure|Comedy|Family|Fantasy : ['Adventure|Comedy|Family|Fantasy', 'Action|Adventure|Drama|Fantasy']
# Action|Adventure|Drama|Thriller : ['Action|Adventure|Thriller']
# Action|Adventure|Thriller : ['Action|Adventure|Drama|Thriller']
# Action|Drama|History|War : ['Action|Drama|War']
# Crime|Thriller : ['comedy thriller', 'thriller comedy', 'dramedy thriller']
# Action|Comedy|Crime|Romance|Thriller : ['action thriller romance drama comedy']
# Biography|Drama : ['drama biography', 'biography drama', 'biography drama ', 'dramatic biography', 'biography war drama', 'biographical drama', 'drama biographical', 'biographical drama ', 'biography crime drama', 'crime drama biography']
# Adventure|Comedy|Family|Fantasy : ['Action|Adventure|Comedy|Family|Fantasy']
# Action|Comedy|Crime|Sci-Fi|Thriller : ['Action|Comedy|Crime|Romance|Thriller']
# Action|Adventure|Crime : ['Action|Adventure|Thriller', 'Action|Adventure|Sci-Fi', 'crime adventure', 'adult action crime']
# Adventure|Animation|Comedy|Family|Fantasy : ['Adventure|Comedy|Family|Fantasy']
# Action|Drama|Sci-Fi|Sport : ['drama action sci fi spy', 'drama tokusatsu action sci fi']
# Adventure|Animation|Comedy|Family|Fantasy : ['Adventure|Animation|Comedy|Family|Fantasy']
# Action|Crime|Romance|Thriller : ['crime thriller romance', 'thriller action romance musical', 'romance comedy thriller']
# Action|Sci-Fi : ['Action|Sci-Fi']
# Action|Adventure|Thriller : ['Action|Adventure|Crime']
# Action|Adventure|Comedy : ['comedy adventure', 'adventure comedy']
# Biography|Drama|Sport : ['biography sports comedy drama', 'Biography|Drama', 'biography sports']
# Adventure|Comedy|Family|Fantasy : ['Adventure|Animation|Comedy|Family|Fantasy']
# Action|Adventure|Drama|History|War : ['Action|Drama|History|War']
# Adventure|Comedy|Family|Fantasy : ['Adventure|Comedy|Family|Fantasy']
# Animation|Family|Fantasy|Musical|Romance : ['action fantasy romance musical']
# Comedy : ['comedy', 'comedy ', 'comedey']
# Comedy|Romance : ['comedy romance', 'romance comedy', 'comedy romance ', 'romantic comedy', 'romantic comedy ', 'romanctic comedy', 'teen romance comedy', 'dark comedy romance', 'Comedy|Drama|Romance', 'romantic comedy teen']
# Action|Crime|Thriller : ['Action|Crime|Romance|Thriller', 'Action|Thriller', 'Crime|Thriller']
# Action|Drama|Romance : ['action drama family romance', 'action fantay romance', 'family romance action', 'action drama musical romance', 'action romance', 'romance action', 'action romance ']
# Action|Adventure|Thriller : ['Action|Adventure|Thriller']
# Action|Adventure|Sci-Fi|Thriller : ['Action|Adventure|Thriller']
# Action|Sci-Fi : ['Action|Sci-Fi']
# Biography|Crime|Drama : ['biogtaphy crime drama', 'biography comedy drama', 'biography crime', 'crime biography']
# Action|Comedy|Thriller : ['Action|Crime|Thriller', 'thriller black comedy', 'black comedy thriller', 'action horror comedy', 'comedy action horror', 'horror action comedy']
# Action|Crime|Thriller : ['Action|Comedy|Thriller']
# Comedy|Romance : ['Comedy|Romance', 'black comedy romance', 'comedy crime romance', 'adult romance comedy', 'romance comedy crime', 'crime romance', 'romance crime', 'comedy road', 'Action|Comedy|Romance', 'horror romance comedy']
# Action|Comedy|Crime : ['action comedy crime drama', 'action comedy drama crime', 'drama action comedy crime', 'action comedy', 'comedy action', 'action comedy ']
# Drama|Western : ['western drama', 'drama western', 'western d', 'drama western crime']
# Animation|Drama|Family|Musical|Romance : ['action drama family musical romance', 'drama family musical romance', 'drama romance musical family', 'drama romance family musical', 'musical drama romance family ', 'Animation|Family|Fantasy|Musical|Romance']
# Adventure|Animation|Comedy|Family|Fantasy : ['Adventure|Comedy|Family|Fantasy']
# Action|Adventure|Thriller : ['Action|Adventure|Sci-Fi|Thriller']
# Adventure|Animation|Family|Fantasy : ['Adventure|Animation|Comedy|Family|Fantasy']
# Action|Romance|Thriller : ['Action|Crime|Thriller', 'romance thriller', 'thriller romance', 'romance science fiction thriller', 'romance drama thriller', 'romance thriller drama', 'drama romance thriller', 'drama romance thriller ']
# Adventure|Drama|Thriller : ['Adventure|Drama|Thriller|Western', 'adventure historical drama']
# Biography|Comedy|Crime|Drama : ['Biography|Crime|Drama']
# Action|Sci-Fi|War : ['Action|Sci-Fi', 'social war action', 'action film war']
# Drama|Sci-Fi : ['sci fi drama', 'sci fi d']
# Action|Adventure|Animation|Family|Fantasy : ['Adventure|Animation|Family|Fantasy']
# Action|Adventure : ['Action|Adventure|Comedy']
# Adventure|Comedy|Sci-Fi : ['superhero comedy adventure sci fi']
# Action|Adventure|Thriller : ['Action|Adventure|Thriller']
# Action|Comedy|Sci-Fi : ['science fiction action comedy']
# Action|Drama|Thriller|War : ['drama war thriller', 'drama thriller war']
# Drama|Mystery|Thriller : ['drama spy thriller', 'Mystery|Thriller']
# Action|Adventure|Fantasy|Thriller : ['Action|Adventure|Thriller', 'Action|Fantasy|Thriller']
# Crime|Drama : ['crime drama', 'drama crime', 'crime melodrama', 'crime dramedy', 'drama anime', 'anime drama', 'drama true crime']
# Drama|History|Romance|War : ['drama romance history', 'historical drama romance', 'drama family romance war']
# Animation|Comedy|Family|Sport : ['animation sports comedy drama']
# Comedy|Sci-Fi|Thriller : ['spy comedy thriller', 'sci fi thriller']
# Drama|History|War : ['drama history', 'historical drama war', 'war drama historical ', 'drama history western', 'Drama|History|Romance|War', 'social drama history ']
# Comedy : ['Comedy']
# Action|Adventure|Sci-Fi : ['Action|Adventure']
# Comedy|Drama|Romance : ['comedy drama romance family', 'drama romance social comedy', 'romance comedy drama social', 'romance drama social comedy', 'family comedy romance', 'comedy drama romance musical', 'drama comedy romance musical', 'romance drama comedy musical', 'drama romance comedy musical ', 'comedy romance drama musical']
# Drama|Family|Fantasy|Romance : ['drama family romance', 'drama fantasy family thriller']
# Drama|Fantasy|Thriller : ['Drama|Fantasy|Horror|Thriller', 'family thriller drama', 'drama family thriller', 'family drama thriller', 'teen fantasy drama']
# Action|Adventure|Fantasy : ['Action|Adventure|Fantasy|Thriller', 'Action|Adventure|Sci-Fi']
# Action|Adventure|Fantasy|Thriller : ['Action|Adventure|Fantasy']
# Action|Adventure|Sci-Fi|Thriller : ['Action|Adventure|Fantasy|Thriller']
# Action|Drama|Sci-Fi|Thriller : ['Action|Adventure|Sci-Fi|Thriller', 'Action|Comedy|Crime|Sci-Fi|Thriller']
# Drama|History|War|Western : ['Drama|History|War']
# Action|Adventure|Animation|Family : ['Action|Adventure|Animation|Family|Fantasy']
# Action|Comedy|Crime|Thriller : ['Action|Comedy|Crime']
# Animation|Comedy|Family|Sci-Fi : ['Animation|Comedy|Family|Sport']
# Action|Adventure|Animation|Comedy|Family : ['Action|Adventure|Animation|Family']
# Action|Adventure|Comedy|Crime|Thriller : ['Action|Comedy|Crime|Thriller']
# Action|Comedy : ['animation comedy', 'costume action', 'crime action', 'action crime', 'action crime ']
# Crime|Drama|Mystery|Thriller : ['Drama|Mystery|Thriller', 'political drama crime mystery thriller', 'crime horror mystery thriller', 'comedy drama horror mystery thriller', 'mystery crime drama', 'crime drama mystery', 'drama mystery crime', 'political drama crime mystery', 'drama romance mystery crime']
# Action|Adventure|Crime|Mystery|Thriller : ['Action|Adventure|Comedy|Crime|Thriller']
# Adventure|Drama|History : ['Action|Adventure|Drama|History|War', 'Adventure|Drama|Thriller']
# Action|Adventure|Animation|Family|Fantasy|Sci-Fi : ['Action|Adventure|Animation|Fantasy|Romance|Sci-Fi']
# Drama|History|Thriller|War : ['historical thriller drama']
# Action|Comedy : ['Action|Comedy']
# Action|Animation|Comedy|Sci-Fi : ['animation comedy action', 'Action|Comedy|Sci-Fi']
# Adventure|Drama|Sci-Fi : ['Adventure|Drama|History', 'Adventure|Comedy|Sci-Fi']
# Crime|Mystery|Thriller : ['Crime|Drama|Mystery|Thriller']
# Action|Adventure|Comedy|Crime|Mystery|Thriller : ['Action|Adventure|Crime|Mystery|Thriller']
# Action|Crime|Thriller : ['Action|Romance|Thriller']
# Adventure|Animation|Comedy|Family|Musical : ['Action|Adventure|Animation|Comedy|Family']
# Comedy|Drama|Sci-Fi : ['sci fi comedy drama', 'comedy drama sci fi', 'social drama comedy', 'drama comedy social', 'comedy drama film', 'dramatic comedy', 'sci fi comedy', 'comedy sci fi', 'comedy drama science fiction', 'sex comedy drama']
# Action|Drama|Sci-Fi|Thriller : ['Action|Drama|Sci-Fi|Thriller']
# Action|Crime|Drama|Thriller : ['Action|Crime|Thriller', 'action crime drama family', 'Action|Drama|Thriller|War', 'action drama crime']
# Drama|History|Thriller|War : ['Drama|History|Thriller|War']
# Biography|Drama|Sport : ['Biography|Drama|Sport']
# Action|Family|Fantasy|Musical : ['action family musical']
# Action|Adventure|Drama|Thriller : ['Action|Crime|Drama|Thriller']
# Adventure|Drama|Romance : ['Adventure|Drama|Romance|War']
# Animation|Comedy|Family|Music|Romance : ['Animation|Drama|Family|Musical|Romance', 'comedy musical romance family', 'action comedy drama musical romance']
# Action|Mystery|Thriller : ['Crime|Mystery|Thriller']
# Action|Adventure|Drama|Thriller : ['Action|Adventure|Drama|Thriller']
# Animation|Comedy|Family|Fantasy : ['Animation|Comedy|Family|Sci-Fi']
# Animation|Comedy|Family|Fantasy|Musical|Romance : ['Animation|Comedy|Family|Music|Romance']
# Action|Crime|Mystery|Thriller : ['Action|Mystery|Thriller']
# Action|Comedy|Crime : ['Action|Comedy']
# Comedy|Romance : ['Comedy|Romance', 'Comedy|Drama|Romance', 'romance comedy horror', 'horror comedy romance', 'comedy romance social', 'erotic romance comedy']
# Action|Crime|Drama|Mystery|Thriller : ['Action|Crime|Mystery|Thriller']
# Comedy|Drama|Romance : ['drama romance musical comedy', 'Comedy|Romance', 'romance fantasy comedy', 'comedy romance fantasy', 'romantic drama black comedy', 'Action|Drama|Romance']
# Adventure|Animation|Comedy|Family : ['Adventure|Animation|Comedy|Family|Musical']
# Drama|History|War : ['Drama|History|War|Western']
# Action|Adventure|Comedy|Thriller : ['Action|Adventure|Drama|Thriller', 'Action|Adventure|Comedy|Crime|Mystery|Thriller']
# Action|Adventure|Comedy|Fantasy : ['Action|Comedy|Fantasy']
# Drama|Romance : ['Drama|Romance']
# Adventure|Animation|Comedy|Family|Fantasy : ['Adventure|Animation|Comedy|Family', 'Animation|Comedy|Family|Fantasy']
# Drama|Fantasy|Romance : ['Drama|Family|Fantasy|Romance']
# Action|Drama|Thriller : ['Action|Drama|Sci-Fi|Thriller']
# Comedy|Drama|Music|Musical : ['comedy drama musical', 'drama family musical comedy']
# Action|Comedy|Fantasy|Romance : ['fantasy romantic comedy']
# Action|Adventure|Sci-Fi|Thriller : ['Action|Adventure|Comedy|Thriller']
# Comedy|Romance|Sci-Fi : ['romance sci fi', 'sci fi romance']
# Action|Sci-Fi : ['Action|Sci-Fi|War']
# Comedy|Drama|Fantasy|Romance : ['Drama|Fantasy|Romance', 'Comedy|Drama|Romance']
# Comedy|Fantasy|Horror : ['Comedy|Fantasy|Horror']
# Action|Adventure|Sci-Fi|Thriller : ['Action|Adventure|Sci-Fi|Thriller']
# Action|Adventure|Fantasy|Horror|Sci-Fi : ['Action|Adventure|Drama|Horror|Sci-Fi']
# Comedy|Drama : ['comedy drama', 'drama comedy', 'comedy drama ', 'comedic drama', 'comedy drama war', 'comedy drama teen', 'costume drama', 'comedy drama anime']
# Action|Adventure|Thriller : ['Action|Adventure|Sci-Fi|Thriller']
# Action|Adventure|Thriller : ['Action|Adventure|Thriller']
# Adventure|Drama|Sci-Fi|Thriller : ['Adventure|Drama|Sci-Fi']
# Comedy : ['Comedy']
# Action : ['Action']
# Adventure|Animation|Comedy|Family : ['Adventure|Animation|Comedy|Family|Fantasy']
# Adventure|Animation|Comedy|Drama|Family|Fantasy|Sci-Fi : ['Action|Adventure|Animation|Family|Fantasy|Sci-Fi']
# Action|Comedy|Crime|Thriller : ['Action|Comedy|Crime']
# Comedy|Crime|Sport : ['comedy drama sports', 'Comedy|Crime', 'comedy short film']
# Adventure|Animation|Comedy|Family|Fantasy|Music : ['Adventure|Animation|Comedy|Drama|Family|Fantasy|Sci-Fi', 'Adventure|Animation|Comedy|Family']
# Comedy : ['Comedy']
# Action|Adventure|Comedy : ['Action|Adventure|Comedy|Fantasy']
# Comedy|Drama|Romance : ['Comedy|Drama|Fantasy|Romance']
# Comedy|Drama|Romance : ['Comedy|Drama|Romance']
# Adventure|Animation|Comedy|Family|Sci-Fi : ['Adventure|Animation|Comedy|Family|Fantasy|Music']
# Action|Crime|Sci-Fi|Thriller : ['Comedy|Sci-Fi|Thriller']
# Crime|Drama|Thriller : ['Action|Drama|Thriller']
# Comedy|Romance : ['Comedy|Drama|Romance', 'Comedy|Romance|Sci-Fi']
# Action|Adventure|Crime|Drama|Sci-Fi|Thriller : ['Adventure|Drama|Sci-Fi|Thriller']
# Action|Crime|Thriller : ['Action|Comedy|Crime|Thriller', 'Action|Crime|Sci-Fi|Thriller']
# Action|Mystery|Thriller : ['Action|Crime|Thriller']
# Action|Adventure|Drama|Thriller : ['Action|Adventure|Thriller', 'Action|Adventure|Crime|Drama|Sci-Fi|Thriller']
# Comedy|Family|Sci-Fi : ['comedy family film', 'Comedy|Drama|Sci-Fi']
# Adventure|Animation|Comedy|Family|Fantasy|Sci-Fi|Sport : ['Adventure|Animation|Comedy|Family|Sci-Fi']
# Action|Crime|Mystery|Romance|Thriller : ['Action|Crime|Drama|Mystery|Thriller']
# Action|Adventure|Comedy|Romance : ['Action|Adventure|Comedy']
# Comedy|Family|Romance : ['family crime drama romance', 'Comedy|Romance', 'family romance']
# Action|Adventure|Family|Sci-Fi|Thriller : ['Action|Adventure|Drama|Thriller']
# Drama|Romance : ['Drama|Romance']
# Animation|Family|Fantasy|Music : ['Action|Family|Fantasy|Musical']
# Action|Adventure|Family|Fantasy|Thriller : ['Action|Adventure|Family|Sci-Fi|Thriller']
# Comedy|Fantasy : ['dramedy fantasy', 'costume fantasy', 'fantasy costume', 'Comedy|Fantasy|Horror']
# Action|Adventure|Comedy|Fantasy|Thriller : ['Action|Adventure|Family|Fantasy|Thriller']
# Action|Comedy|Sci-Fi : ['Action|Animation|Comedy|Sci-Fi']
# Drama|Horror|Mystery|Sci-Fi : ['Drama|Horror|Sci-Fi']
# Action|Adventure|Drama|Thriller : ['Action|Adventure|Comedy|Fantasy|Thriller']
# Action|Sci-Fi|Thriller : ['action thriller science fiction', 'action science fiction thriller']
# Drama|History|Thriller : ['Drama|History|Thriller|War', 'biography drama history thriller']
# Action|Adventure|Drama|Thriller : ['Action|Adventure|Drama|Thriller']
# Adventure|Animation|Family : ['animation adventure']
# Adventure|Animation|Comedy|Family|Fantasy|Sci-Fi : ['Adventure|Animation|Comedy|Family|Fantasy|Sci-Fi|Sport']
# Drama|Musical|Romance : ['drama musical romance', 'drama romance musical', 'musical drama romance', 'romance drama musical', 'drama romance musical ', 'drama musical romance ', 'drama romance musical crime', 'drama romance musical social', 'drama romance social musical', 'drama social musical romance']
# Action|Adventure|Drama|Sci-Fi : ['Action|Adventure|Drama|Thriller']
# Action|Sci-Fi|Thriller : ['Action|Sci-Fi|Thriller']
# Adventure|Animation|Family|Fantasy : ['Adventure|Animation|Family', 'Adventure|Animation|Comedy|Family|Fantasy|Sci-Fi']
# Documentary|Drama : ['documentary drama', 'drama documentary', 'documentary family']
# Animation|Family : ['animation family', 'family animation', 'animated family', 'family animated', 'clay animation', 'animation family romance ']
# Biography|Drama : ['Biography|Drama|Sport', 'action biography drama', 'drama biography action', 'action drama biography']
# Animation|Comedy|Family|Fantasy|Sci-Fi : ['Animation|Comedy|Family|Fantasy|Musical|Romance']
# Crime|Drama|Thriller : ['Crime|Drama|Thriller']
# Comedy : ['Comedy']
# Action|Crime|Thriller : ['Action|Sci-Fi|Thriller']
# Adventure|Animation|Drama|Family|Fantasy : ['Adventure|Animation|Family|Fantasy']
# Sci-Fi|Thriller : ['social thriller', 'thriller social']
# Adventure|Animation|Comedy|Family|Fantasy : ['Adventure|Animation|Drama|Family|Fantasy']
# Animation|Comedy|Family : ['animated comedy family', 'Animation|Family']
# Action|Adventure|Fantasy|Sci-Fi : ['Action|Adventure|Fantasy|Horror|Sci-Fi', 'Action|Adventure|Drama|Sci-Fi']
# Animation|Comedy|Family|Sci-Fi : ['Animation|Comedy|Family|Fantasy|Sci-Fi', 'Animation|Comedy|Family', 'Comedy|Family|Sci-Fi']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Fantasy|Sci-Fi']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Sci-Fi']
# Adventure|Animation|Comedy|Family : ['Adventure|Animation|Comedy|Family|Fantasy']
# Drama|Sci-Fi|Thriller : ['Sci-Fi|Thriller']
# Action|Adventure|Sci-Fi : ['Action|Adventure|Sci-Fi']
# Action|Crime|Fantasy|Thriller : ['Action|Crime|Thriller']
# Action|Adventure|Animation|Comedy|Family|Fantasy : ['Adventure|Animation|Comedy|Family']
# Comedy|Romance : ['Comedy|Family|Romance']
# Comedy|Drama|Family|Music|Musical|Romance : ['drama romance comedy family musical social ', 'drama romance musical comedy family social']
# Horror|Mystery|Thriller : ['horror mystery romance thriller ']
# Crime|Mystery|Thriller : ['Action|Mystery|Thriller', 'Horror|Mystery|Thriller']
# Comedy : ['Comedy']
# Comedy|Drama : ['Comedy|Drama']
# Drama|Fantasy|Horror|Thriller : ['Drama|Fantasy|Thriller']
# Comedy|Family : ['family comedy', 'comedy family', 'comedy film', 'comedy drama family', 'family comedy drama', 'family drama comedy', 'comedy family drama', 'drama comedy family', 'crime family']
# Adventure|Animation|Comedy|Family : ['Action|Adventure|Animation|Comedy|Family|Fantasy']
# Drama|Music|Musical : ['Comedy|Drama|Music|Musical', 'drama family musical', 'drama musical', 'musical drama', 'drama musical ']
# Crime|Drama|Mystery : ['drama mystery', 'crime mystery', 'mystery drama']
# Drama|History|Thriller : ['Drama|History|Thriller']
# Action|Comedy|Romance|Thriller : ['Action|Crime|Mystery|Romance|Thriller', 'comedy romantic thriller']
# Action|Adventure|Comedy : ['Action|Adventure|Comedy|Romance']
# Comedy|Drama|Romance : ['Comedy|Romance']
# Comedy|Crime|Drama|Romance : ['drama family crime romance comedy', 'action comedy crime drama romance', 'Comedy|Drama|Romance']
# Drama|History|Romance : ['drama mystery romance', 'romance drama mystery', 'drama romance mystery', 'historical romantic drama', 'history romance ']
# Action|Drama|Fantasy|Romance : ['Action|Comedy|Fantasy|Romance']
# Action|Crime|Drama|Mystery|Thriller : ['Action|Crime|Fantasy|Thriller']
# Action|Comedy|Crime|Thriller : ['Action|Comedy|Romance|Thriller']
# Action|Drama|Sci-Fi : ['drama sci fi kaiju action', 'Action|Drama|Sci-Fi|Sport', 'Action|Drama|Mystery|Sci-Fi', 'Action|Sci-Fi', 'action drama science fiction', 'drama action science fiction']
# Drama|Horror|Sci-Fi|Thriller : ['Drama|Sci-Fi|Thriller', 'Drama|Fantasy|Horror|Thriller']
# Animation|Comedy|Fantasy : ['animated fantasy', 'fantasy animated']
# Drama|Mystery|Sci-Fi|Thriller : ['Drama|Horror|Sci-Fi|Thriller']
# Action|Animation|Comedy|Family|Sci-Fi : ['Animation|Comedy|Family|Sci-Fi']
# Crime|Mystery|Thriller : ['Crime|Mystery|Thriller']
# Drama|Mystery|Sci-Fi|Thriller : ['Drama|Mystery|Sci-Fi|Thriller']
# Action|Animation|Comedy|Family : ['Action|Animation|Comedy|Family|Sci-Fi', 'animation live action drama comedy', 'Adventure|Animation|Comedy|Family', 'animation martial arts action comedy', 'animation action comedy martial arts']
# Comedy|Drama : ['Comedy|Drama']
# Action|Drama|Thriller : ['Crime|Drama|Thriller']
# Action|Comedy|Sport : ['action comedy parody', 'action comedy superhero', 'action mystery comedy', 'action sports romance']
# Comedy|Family|Fantasy : ['Comedy|Fantasy']
# Adventure|Animation|Comedy : ['adventure animated comedy', 'adventure animated', 'animated adventure']
# Drama|Romance : ['Drama|Romance']
# Action|Drama|Sport : ['Action|Family|Sport', 'school action drama']
# Drama|Mystery|Romance|Thriller : ['drama romance youth mystery', 'drama romance thriller musical', 'Drama|Mystery|Sci-Fi|Thriller']
# Comedy|Family|Fantasy : ['Comedy|Family|Fantasy']
# Adventure|Animation|Comedy|Family|Sport : ['Adventure|Animation|Comedy']
# Adventure|Animation|Comedy|Family|Fantasy : ['Adventure|Animation|Comedy|Family|Sport']
# Adventure|Drama|War : ['Adventure|Drama|Romance']
# Adventure|Comedy|Family|Fantasy : ['Adventure|Animation|Comedy|Family|Fantasy', 'Comedy|Family|Fantasy']
# Action|Adventure : ['Action|Adventure|Sci-Fi', 'Action|Adventure|Comedy']
# Action|Thriller : ['Action|Drama|Thriller']
# Fantasy|Mystery|Romance|Sci-Fi|Thriller : ['fantasy horror romance sci fi thriller']
# Drama|Fantasy|Mystery|Thriller : ['political fantasy drama mystery thriller']
# Animation|Comedy|Family|Fantasy|Music : ['Animation|Family|Fantasy|Music']
# Action|Drama|History|War : ['Drama|History|War']
# Action|Thriller : ['Action|Thriller']
# Action|Sci-Fi : ['Action|Drama|Sci-Fi']
# Adventure|Drama|Fantasy : ['Adventure|Drama|War']
# Drama|Horror|Romance|Thriller : ['romance horror thriller', 'Drama|Mystery|Romance|Thriller']
# Drama|War : ['war drama', 'drama war', 'wartime drama']
# Drama|War : ['Drama|War']
# Drama : ['drama', 'drama ']
# Action|Drama|Fantasy|Horror|War : ['Action|Drama|Fantasy|Romance']
# Action|Thriller : ['Action|Thriller']
# Comedy|Drama : ['Comedy|Drama']
# Action|Fantasy|Horror : ['Action|Drama|Fantasy|Horror|War']
# Comedy|Drama|Musical|Romance : ['musical comedy romance', 'comedy romance musical', 'Drama|Musical|Romance', 'musical romantic comedy', 'Comedy|Drama|Family|Music|Musical|Romance']
# Drama|War : ['Drama|War']
# Action|Crime|Thriller : ['Action|Comedy|Crime|Thriller', 'Action|Thriller']
# Action|Sci-Fi|Sport : ['Action|Sci-Fi']
# Action|Crime|Sci-Fi|Thriller : ['Action|Crime|Thriller']
# Action|Crime|Drama|Thriller : ['Action|Crime|Drama|Mystery|Thriller', 'Action|Crime|Sci-Fi|Thriller']
# Adventure|Animation|Family|Fantasy|Musical : ['animation fantasy adventure martial arts']
# Action|Crime|Drama|Mystery|Thriller : ['Action|Crime|Drama|Thriller']
# Crime|Mystery|Thriller : ['Crime|Mystery|Thriller']
# Action|Crime|Mystery|Sci-Fi|Thriller : ['Action|Crime|Drama|Mystery|Thriller', 'political drama action sci fi mystery thriller']
# Action|Adventure|Fantasy : ['Action|Adventure']
# Adventure|Drama|Fantasy|Romance : ['Adventure|Drama|Fantasy']
# Animation|Comedy|Family : ['Action|Animation|Comedy|Family', 'Animation|Comedy|Fantasy']
# Action|Comedy|Crime|Drama|Thriller : ['crime thriller dark comedy']
# Comedy : ['Comedy']
# Adventure|Drama|History|Romance : ['Adventure|Drama|Fantasy|Romance', 'Drama|History|Romance']
# Action|Comedy|Fantasy|Sci-Fi : ['Action|Comedy|Sci-Fi']
# Biography|Drama|Thriller : ['biography drama thriller', 'biography spy thriller']
# Action|Drama|History|Thriller : ['Drama|History|Thriller', 'Action|Drama|History|War']
# Action|Drama|Thriller : ['Action|Drama|History|Thriller']
# Comedy : ['Comedy']
# Action|Fantasy|Horror : ['Action|Fantasy|Horror']
# Comedy : ['Comedy']
# Drama|Mystery|Sci-Fi|Thriller : ['Drama|Fantasy|Mystery|Thriller', 'Action|Crime|Mystery|Sci-Fi|Thriller']
# Action|Adventure|Fantasy|War : ['Action|Adventure|Fantasy']
# Action|Drama|War : ['Action|Drama|Sport']
# Action|Crime|Drama|Thriller : ['Action|Comedy|Crime|Drama|Thriller', 'Action|Drama|Thriller']
# Adventure|Animation|Comedy|Family : ['Animation|Comedy|Family']
# Drama|Horror|Sci-Fi|Thriller : ['Drama|Mystery|Sci-Fi|Thriller', 'Drama|Horror|Romance|Thriller']
# Action|Sci-Fi : ['Action|Sci-Fi|Sport']
# Adventure|Drama|History : ['Adventure|Drama|History|Romance']
# Action|Sci-Fi : ['Action|Sci-Fi']
# Comedy|Family|Fantasy : ['Adventure|Comedy|Family|Fantasy']
# Drama|Musical|Romance : ['Comedy|Drama|Musical|Romance', 'musical social drama romance', 'family musical romance', 'romance musical', 'musical romance', 'fantasy musical romance', 'romance fantasy musical ']
# Comedy|Drama|Romance : ['Comedy|Crime|Drama|Romance']
# Comedy : ['Comedy']
# Comedy|Drama : ['Comedy|Drama']
# Action|Crime|Thriller : ['Action|Crime|Drama|Thriller']
# Comedy|Family|Fantasy : ['Comedy|Family|Fantasy']
# Drama : ['Drama']
# Comedy|Romance : ['Comedy|Drama|Romance']
# Drama|Mystery|Thriller : ['Crime|Mystery|Thriller']
# Action|Comedy|Romance : ['action comedy romance musical', 'action romance period', 'Comedy|Romance', 'rom com action']
# Action|Drama|War : ['Action|Drama|War']
# Comedy|Drama : ['Comedy|Drama']
# Action|Horror|Sci-Fi|Thriller : ['Drama|Horror|Sci-Fi|Thriller']
# Action|Sci-Fi|Thriller : ['Action|Horror|Sci-Fi|Thriller']
# Action|Drama|Thriller : ['Action|Crime|Thriller']
# Drama : ['Drama']
# Drama|Sport : ['drama sport', 'sport drama', 'drama sports', 'sports drama', 'short drama', 'spy drama']
# Crime|Drama|Mystery : ['Crime|Drama|Mystery']
# Comedy|Crime : ['Comedy|Crime|Sport']
# Action|Fantasy|Sci-Fi|Thriller : ['Action|Sci-Fi|Thriller']
# Crime|Drama : ['Crime|Drama']
# Action|Crime|Thriller : ['Action|Drama|Thriller']
# Crime|Drama|Fantasy : ['fantasy drama', 'drama fantasy', 'crime drama family', 'drama crime family', 'family crime drama']
# Action|Comedy|Crime : ['Action|Comedy|Romance']
# Action|Crime|Drama|Thriller : ['Action|Crime|Thriller']
# Action|Adventure|Drama|History : ['Adventure|Drama|History']
# Comedy|Crime : ['Comedy|Crime']
# Action|War : ['war action', 'action war']
# Comedy|Romance|Sport : ['romantic comedy sports']
# Action|Comedy|Crime|Thriller : ['Action|Comedy|Crime']
# Comedy|Sport : ['comedy sports', 'sports comedy', 'comedy short', 'short comedy', 'comedy spy', 'pow comedy', 'spy comedy']
# Adventure|Animation|Comedy|Family|Fantasy : ['Adventure|Animation|Comedy|Family', 'Adventure|Animation|Family|Fantasy|Musical']
# Action|Drama|Fantasy|War : ['Action|Adventure|Fantasy|War', 'Action|Drama|War']
# Comedy|Romance : ['Comedy|Romance|Sport']
# Comedy|Drama|Family : ['action family drama comedy', 'action drama family comedy', 'Comedy|Family', 'animated comedy drama family']
# Crime|Drama|Fantasy|Mystery : ['anime drama mystery fantasy', 'fantasy drama comedy mystery', 'Crime|Drama|Fantasy', 'Crime|Drama|Mystery']
# Adventure|Animation|Comedy|Family|Sci-Fi : ['Adventure|Animation|Comedy|Family|Fantasy']
# Crime|Drama|Mystery|Thriller : ['Drama|Mystery|Thriller']
# Drama|Mystery|Thriller : ['Crime|Drama|Mystery|Thriller']
# Comedy|Family : ['Comedy|Drama|Family']
# Action|Comedy|Crime|Drama|Thriller : ['Action|Comedy|Crime|Thriller', 'Action|Crime|Drama|Thriller']
# Action|Comedy|Family|Fantasy : ['Comedy|Family|Fantasy', 'Animation|Comedy|Family|Fantasy|Music']
# Comedy|Romance : ['Comedy|Romance']
# Adventure|Animation|Comedy|Family : ['Adventure|Animation|Comedy|Family|Sci-Fi']
# Comedy : ['Comedy']
# Adventure|Comedy|Family : ['Adventure|Animation|Comedy|Family']
# Action|Sci-Fi|Thriller : ['Action|Fantasy|Sci-Fi|Thriller']
# Drama|Romance : ['Drama|Romance']
# Action|Comedy|Crime|Thriller : ['Action|Comedy|Crime|Drama|Thriller']
# Drama|Sport : ['Drama|Sport']
# Drama|Romance|Western : ['western romantic drama', 'western romance']
# Action|Sci-Fi|Thriller : ['Action|Sci-Fi|Thriller']
# Documentary|Music : ['documentary music']
# Drama|Thriller : ['thriller d']
# Sci-Fi|Thriller : ['Action|Sci-Fi|Thriller']
# Comedy|Family|Fantasy : ['Action|Comedy|Family|Fantasy']
# Comedy|Crime : ['Comedy|Crime']
# Comedy|Family : ['Comedy|Family']
# Action|Fantasy|Horror|Sci-Fi : ['Action|Fantasy|Horror']
# Drama : ['Drama']
# Drama|Romance : ['Drama|Romance']
# Comedy|Romance : ['Comedy|Romance']
# Action|Comedy|Sci-Fi : ['Action|Comedy|Fantasy|Sci-Fi']
# ...
# Drama|Horror|Mystery|Thriller : ['Drama|Horror|Mystery|Thriller']
# Documentary : ['Documentary']
# Horror : ['Horror']
# Action|Horror|Thriller : ['Horror|Thriller']
# Horror : ['Horror']
# Adventure|Family|Fantasy|Musical : ['Family|Fantasy|Musical']
# Comedy : ['Comedy']
# Horror : ['Horror']
# Drama : ['Drama']
# Romance : ['romance', 'romance ', 'romantic']
# Comedy|Western : ['Comedy|Western']
# Horror|Thriller : ['Action|Horror|Thriller']
# Drama : ['Drama']
# Documentary|History|Sport : ['Documentary|Sport']
# Horror|Mystery|Sci-Fi|Thriller : ['Drama|Horror|Mystery|Thriller']
# Action|Adventure|Comedy : ['Action|Adventure|Crime|Drama']
# Horror|Thriller : ['Horror|Thriller']
# Comedy|Musical|Romance : ['Musical|Romance']
# Documentary : ['Documentary']
# Documentary : ['Documentary']
# Horror : ['Horror']
# Horror|Mystery|Sci-Fi : ['Horror|Mystery|Sci-Fi|Thriller']
# Drama : ['Drama']
# Comedy|Documentary : ['Comedy|Documentary']
# Drama : ['Drama']
# Drama : ['Drama']
# Drama : ['Drama']
# Comedy|Documentary|War : ['Comedy|Documentary']
# Documentary : ['Documentary']
# Drama : ['Drama']
# Documentary : ['Documentary']
# Horror|Thriller : ['Horror|Thriller']
# Comedy|Horror : ['Comedy|Drama|Horror']
# Horror : ['Horror']
# Crime|Drama : ['Crime|Drama']
# Crime|Drama : ['Crime|Drama']
# Comedy|Sci-Fi : ['Comedy|Music|Sci-Fi']
# Drama|Musical : ['Drama|Music']
# Drama : ['Drama']
# Horror|Thriller : ['Horror|Thriller']
# Drama : ['Drama']
# Drama : ['Drama']
# Drama : ['Drama']
# Comedy|Music|Romance : ['Comedy|Musical|Romance']
# Crime|Drama : ['Crime|Drama']
# Horror : ['Horror']
# Drama : ['Drama']
# Horror|Sci-Fi|Thriller : ['Horror|Thriller']
# Adventure|Drama|Western : ['Adventure|Drama|War']
# Comedy|Sci-Fi : ['Comedy|Sci-Fi']
# Horror|Mystery : ['Horror|Mystery|Sci-Fi']
# Comedy : ['Comedy']
# Crime|Drama : ['Crime|Drama']
# Action|Comedy : ['Action|Crime']
# Drama : ['Drama']
# Drama|Sport : ['Drama|Sport']
# Adventure|Drama|Romance|Western : ['Adventure|Drama|Western']
# Drama : ['Drama']
# Drama : ['Drama']
# Comedy|Romance : ['Comedy|Music|Romance']
# Comedy : ['Comedy']
# Drama : ['Drama']
# Comedy|Drama|Romance : ['Comedy|Romance']
# Adventure : ['Adventure']
# Documentary|War : ['Documentary', 'nature documentary', 'Documentary|Drama|War', 'Comedy|Documentary|War']
# Comedy|Drama|Romance : ['Comedy|Drama|Romance']
# Documentary|History : ['Documentary|History|Sport']
# Crime|Drama|Romance : ['Comedy|Drama|Romance']
# Comedy : ['Comedy']
# Action|Adventure|Comedy|Drama|Music|Sci-Fi : ['action adventure comedy drama science fiction musical fantasy']
# Biography|Comedy|Drama|Music : ['Biography|Comedy|Musical']
# Drama : ['Drama']
# Comedy|Drama|Sci-Fi : ['Comedy|Sci-Fi']
# Crime|Drama : ['Crime|Drama']
# Adventure|Family|Fantasy : ['Adventure|Family|Fantasy|Musical']
# Drama : ['Drama']
# Drama|Romance : ['Crime|Drama|Romance']
# Drama : ['Drama']
# Horror|Thriller : ['Horror|Sci-Fi|Thriller']
# Horror : ['Horror']
# Comedy|Horror : ['Comedy|Horror']
# Documentary : ['Documentary|War']
# Comedy : ['Comedy']
# Horror|Thriller : ['Horror|Thriller']
# Crime|Drama : ['Crime|Drama']
# Comedy : ['Comedy']
# Horror|Mystery : ['Horror|Mystery']
# Documentary : ['Documentary']
# Comedy|Horror : ['Comedy|Horror']
# Crime|Drama : ['Crime|Drama']
# Drama : ['Drama']
# Drama|Musical : ['Drama|Musical']
# Horror : ['Horror']
# Drama : ['Drama']
# Drama : ['Drama']
# Drama|Horror|Thriller : ['Horror|Thriller']
# Biography|Drama|Music : ['Biography|Comedy|Drama|Music']
# Drama : ['Drama']
# Comedy : ['Comedy']
# Drama|Romance : ['Drama|Romance']
# Drama|Music : ['Drama|Musical']
# Drama : ['Drama']
# Comedy|Horror : ['Comedy|Horror']
# Western : ['Western']
# Crime|Drama|Film-Noir : ['crime film noir']
# Horror|Thriller : ['Drama|Horror|Thriller']
# Comedy|Horror|Thriller : ['Horror|Thriller']
# Crime|Drama : ['Crime|Drama']
# Drama|Horror : ['Drama|Horror']
# Adventure|Family : ['Adventure|Family|Fantasy']
# Horror : ['Horror']
# Crime|Drama : ['Crime|Drama']
# Horror|Thriller : ['Comedy|Horror|Thriller']
# Drama|Romance : ['Drama|Romance']
# Drama|Romance : ['Drama|Romance']
# Drama|Romance : ['Drama|Romance']
# Drama|Romance|War : ['Drama|Romance']
# Western : ['Western']
# Drama|Music : ['Drama|Music']
# Horror|Thriller : ['Horror|Thriller']
# Romance : ['Romance']
# Horror : ['Horror']
# Action|Horror|Thriller : ['Horror|Thriller']
# Drama : ['Drama']
# Action : ['Action']
# Documentary|War : ['Documentary']
# Drama : ['Drama']
# Drama : ['Drama']
# Drama|Romance : ['Drama|Romance|War']
# Action|Horror|Thriller : ['Action|Horror|Thriller']
# Horror|Mystery : ['Horror|Mystery']
# Comedy|Horror : ['Comedy|Horror']
# Drama : ['Drama']
# Comedy : ['Comedy']
# Drama|Music|Romance : ['Drama|Romance']
# Drama|War : ['Drama|War']
# Drama : ['Drama']
# Comedy|Horror|Mystery : ['Horror|Mystery']
# Documentary : ['Documentary|War']
# Sci-Fi : ['Sci-Fi']
# Action|Horror|Thriller : ['Action|Horror|Thriller']
# Drama : ['Drama']
# Western : ['Western']
# Drama : ['Drama']
# Horror|Thriller : ['Action|Horror|Thriller']
# Horror|Thriller : ['Horror|Thriller']
# Adventure|Comedy|Family : ['Adventure|Family']
# Western : ['Western']
# Drama : ['Drama']
# Drama : ['Drama']
# Drama : ['Drama']
# Comedy|Horror : ['Comedy|Horror']
# Drama|Sci-Fi : ['Drama|Sci-Fi']
# Comedy : ['Comedy']
# Comedy : ['Comedy']
# Drama|Film-Noir : ['Crime|Drama|Film-Noir', 'drama noir']
# Drama|Music : ['Drama|Music']
# Animation : ['Animation']
# Drama : ['Drama']
# Drama : ['Drama']
# Comedy|Crime|Mystery : ['Comedy|Crime|Mystery']
# Drama : ['Drama']
# Drama|Sport : ['Drama|Sport']
# Western : ['Western']
# Documentary : ['Documentary']
# Drama : ['Drama']
# Adventure|Comedy|Drama : ['Adventure|Comedy|Family']
# Comedy : ['Comedy']
# Adventure|Comedy|Sport : ['Adventure|Comedy|Drama']
# Action|Comedy : ['Action|Comedy']
# Horror : ['Horror']
# Horror : ['Horror']
# Comedy : ['Comedy']
# Drama|Horror|Thriller : ['Horror|Thriller']
# Action|Drama|Horror|Thriller : ['Drama|Horror|Thriller']
# Drama : ['Drama']
# Horror : ['Horror']
# Drama|Sci-Fi : ['Drama|Sci-Fi']
# Drama|Sport : ['Drama|Sport']
# Drama : ['Drama']
# Adventure|Comedy|History : ['Adventure|Comedy|Sport']
# Crime|Drama : ['Crime|Drama']
# Horror : ['Horror']
# Drama : ['Drama']
# Drama|Romance : ['Drama|Music|Romance']
# Horror : ['Horror']
# Comedy|Drama|Music : ['Comedy|Drama|Sci-Fi']
# Drama|Romance|Western : ['Adventure|Drama|Romance|Western']
# Documentary : ['Documentary']
# Documentary : ['Documentary']
# Drama : ['Drama']
# Comedy|Drama : ['Comedy|Drama|Music']
# Comedy|Drama : ['Comedy|Drama']
# Crime|Drama : ['Crime|Drama']
# Comedy|Drama : ['Comedy|Drama']
# Comedy|Drama|Music : ['Comedy|Drama']
# Documentary : ['Documentary']
# Drama : ['Drama']
# Drama|Romance : ['Drama|Romance']
# Comedy : ['Comedy']
# Drama|Romance : ['Drama|Romance']
# Comedy|Drama : ['Comedy|Drama|Music']
# Drama : ['Drama']
# Drama : ['Drama']
# Crime|Drama : ['Crime|Drama']
# Documentary|Sport : ['Documentary|History']
# Drama : ['Drama']
# Comedy|Drama : ['Comedy|Drama']
# Documentary : ['Documentary']
# Action|Drama : ['Action|Drama|Sport']
# Horror : ['Horror']
# Crime|Drama|Romance : ['Drama|Romance']
# Comedy|Drama : ['Comedy|Drama']
# Drama|Sci-Fi : ['Drama|Sci-Fi']
# Comedy|Drama : ['Comedy|Drama']
# Action|Adventure|Comedy|Fantasy|Sci-Fi : ['Action|Adventure|Comedy|Drama|Music|Sci-Fi']
# Action|Drama : ['Action|Drama']
# Comedy|Drama : ['Comedy|Drama']
# Crime|Drama|Romance : ['Crime|Drama|Romance']
# Drama|Romance : ['Crime|Drama|Romance']
# Comedy|Drama : ['Comedy|Drama']
# Comedy : ['Comedy']
# Drama : ['Drama']
# Drama : ['Drama']
# Drama : ['Drama']
# Drama : ['Drama']
# Horror : ['Horror']
# Drama|Romance : ['Drama|Romance']
# Western : ['Western']
# Horror|Mystery : ['Comedy|Horror|Mystery']
# Drama|Musical|Sci-Fi : ['drama musical social']
# Horror : ['Horror']
# Drama : ['Drama']
# Comedy : ['Comedy']
# Drama : ['Drama']
# Documentary|News : ['Documentary']
# Crime|Drama|Romance : ['Drama|Romance']
# Comedy : ['Comedy']
# Drama : ['Drama']
# Horror : ['Horror']
# Drama : ['Drama']
# Biography|Drama|Romance : ['Biography|Drama|Music', 'Adventure|Biography|Drama|Romance']
# Action|Drama|Thriller : ['Action|Drama|Horror|Thriller']
# Comedy|Drama|Romance : ['Crime|Drama|Romance']
# Drama : ['Drama']
# Drama : ['Drama']
# Comedy : ['Comedy']
# Comedy|Drama|Romance : ['Comedy|Drama|Romance']
# Crime|Drama|Thriller : ['Action|Drama|Thriller']
# Comedy|Drama : ['Comedy|Drama']
# Crime|Drama|Romance : ['Comedy|Drama|Romance']
# Drama : ['Drama']
# Drama : ['Drama']
# Drama|Thriller : ['Crime|Drama|Thriller']
# Crime|Drama|Romance : ['Crime|Drama|Romance']
# Drama : ['Drama']
# Comedy : ['Comedy']
# Comedy|Horror : ['Comedy|Horror']
# Comedy|Drama|Music : ['Comedy|Drama']
# Documentary|War : ['Documentary|News', 'Documentary|Sport']
# Action|Adventure|Animation|Comedy|Fantasy|Sci-Fi : ['Action|Adventure|Comedy|Fantasy|Sci-Fi']
# Comedy|Drama|Romance : ['Crime|Drama|Romance']
# Horror : ['Horror']
# Drama : ['Drama']
# Drama : ['Drama']
# Horror : ['Horror']
# Horror : ['Horror']
# Thriller|Western : ['Action|Thriller|Western']
# Crime|Drama : ['Crime|Drama']
# Horror : ['Horror']
# Drama : ['Drama']
# Drama : ['Drama']
# Comedy : ['Comedy']
# Crime|Drama|Thriller : ['Drama|Thriller']
# Documentary : ['Documentary|War']
# Documentary : ['Documentary']
# Drama|Thriller : ['Crime|Drama|Thriller']
# Comedy|Drama : ['Comedy|Drama|Music']
# Comedy|Musical|Romance : ['Comedy|Drama|Romance']
# Horror : ['Horror']
# Comedy : ['Comedy']
# Action|Crime|Drama : ['Action|Drama']
# Drama : ['Drama']
# Crime|Drama : ['Crime|Drama']
# Documentary : ['Documentary']
# Documentary : ['Documentary']
# Action|Drama|Thriller : ['Drama|Thriller']
# Comedy|Drama : ['Comedy|Drama']
# Documentary : ['Documentary']
# Comedy : ['Comedy']
# Comedy : ['Comedy']
# Comedy|Drama : ['Comedy|Drama']
# Drama : ['Drama']
# Documentary : ['Documentary']
# Drama : ['Drama']
# Documentary : ['Documentary']
# Drama|Music : ['Drama|Music']
# Drama : ['Drama']
# Crime|Drama : ['Crime|Drama']
# Crime|Drama|Thriller : ['Action|Drama|Thriller']
# Comedy|Drama : ['Comedy|Drama']
# Documentary : ['Documentary']
# Action|Adventure|Drama : ['Action|Adventure|Comedy']
# Comedy|Music|Romance : ['Comedy|Musical|Romance']
# Comedy : ['Comedy']
# Adventure|Animation|Comedy|Family|Fantasy|Sci-Fi : ['Action|Adventure|Animation|Comedy|Fantasy|Sci-Fi']
# Comedy|Romance : ['Comedy|Music|Romance']
# Drama|Sport : ['Drama|Sport']
# Drama : ['Drama']
# Comedy : ['Comedy']
# Comedy|Horror : ['Comedy|Horror']
# Drama : ['Drama']
# Drama|Thriller : ['Crime|Drama|Thriller']
# Documentary : ['Documentary']
# Comedy|Horror : ['Comedy|Horror']
# History : ['history', 'historic']
# Comedy|Drama : ['Comedy|Drama']
# Crime|Drama : ['Crime|Drama']
# Horror|Musical : ['horror masala', 'Horror|Musical|Sci-Fi']
# Family : ['Family']
# Family : ['Family']
# Crime|Drama : ['Crime|Drama']
# Action : ['Action']
# Comedy|Drama|Romance : ['Comedy|Romance']
# Comedy|Horror|Musical : ['Horror|Musical']
# Comedy|Romance : ['Comedy|Drama|Romance']
# Documentary : ['Documentary']
# Comedy|Drama|Romance : ['Comedy|Romance']
# Comedy|Drama|Music|Romance : ['Comedy|Drama|Romance']
# Comedy : ['Comedy']
# Crime|Drama|Thriller : ['Drama|Thriller']
# Horror : ['Horror']
# Drama : ['Drama']
# Comedy|Fantasy|Horror|Musical : ['Comedy|Horror|Musical']
# Biography|Documentary : ['Biography|Comedy|Documentary']
# Documentary : ['Documentary']
# Comedy|Horror : ['Comedy|Horror']
# Horror : ['Horror']
# Comedy|Drama|Romance : ['Comedy|Drama|Music|Romance']
# Drama|Thriller : ['Crime|Drama|Thriller']
# Drama : ['Drama']
# Documentary : ['Documentary']
# Action|Drama : ['Action|Crime|Drama']
# Documentary : ['Documentary']
# Action|Adventure|Drama|Sci-Fi : ['Action|Adventure|Drama']
# Family|Sci-Fi : ['Family|Sci-Fi']
# Crime|Drama : ['Crime|Drama']
# Animation|Drama : ['drama animated', 'animated drama', 'Action|Drama']
# Comedy|Romance : ['Comedy|Drama|Romance']
# Drama|Thriller : ['Drama|Thriller']
# Biography|Documentary|Music : ['Biography|Documentary']
# Comedy|Drama : ['Comedy|Drama']
# Comedy|Romance : ['Comedy|Romance']
# Comedy|Drama : ['Comedy|Drama']
# Drama : ['Drama']
# Drama : ['Drama']
# Drama : ['Drama']
# Drama : ['Drama']
# Documentary : ['Documentary']
# Documentary : ['Documentary']
# Drama|Sport : ['Drama|Sport']
# Drama|Music : ['Drama|Music']
# Action|Comedy|Sci-Fi|Sport : ['action sci fi comedy spy tokusatsu']
# Horror : ['Horror']
# Comedy|Drama|Romance : ['Comedy|Romance']
# Horror|Mystery : ['Horror|Mystery']
# Comedy|Drama|Romance : ['Comedy|Drama|Romance']
# Comedy|Drama|Romance : ['Comedy|Drama|Romance']
# Crime|Drama|Romance : ['Comedy|Drama|Romance']
# Comedy|Drama|Romance : ['Crime|Drama|Romance']
# Comedy|Drama : ['Comedy|Drama']
# Comedy|Drama|Romance : ['Comedy|Drama|Romance']
# Comedy|Romance : ['Comedy|Drama|Romance']
# Animation|Comedy|Drama|Fantasy|Sci-Fi : ['Adventure|Animation|Comedy|Family|Fantasy|Sci-Fi']
# Horror : ['Horror']
# Comedy|Drama : ['Comedy|Drama']
# Drama|Thriller : ['Drama|Thriller']
# Crime|Drama : ['Crime|Drama']
# Drama : ['Drama']
# Drama|Thriller : ['Drama|Thriller']
# Sci-Fi : ['Sci-Fi']
# Drama|Musical : ['Drama|Music']
# Drama : ['Drama']
# Action|Drama|Fantasy|Sci-Fi : ['Animation|Comedy|Drama|Fantasy|Sci-Fi']
# Comedy|Short : ['Comedy|Horror', 'short black comedy']
# Crime|Drama : ['Crime|Drama']
# Documentary : ['Documentary']
# Family : ['Family']
# Documentary : ['Documentary']
# Drama|Romance|War : ['Drama|Romance|Western']
# Comedy : ['Comedy']
# Comedy|Music|Romance : ['Comedy|Romance']
# Documentary : ['Documentary']
# Drama : ['Drama']
# Comedy|Drama : ['Comedy|Drama']
# Comedy|Drama : ['Comedy|Drama']
# Documentary : ['Documentary']
# Drama : ['Drama']
# Drama : ['Drama']
# Comedy|Drama|Romance : ['Comedy|Music|Romance']
# Drama|Music : ['Drama|Musical']
# Crime|Drama|Thriller : ['Drama|Thriller']
# Comedy|Drama : ['Comedy|Drama']
# Comedy|Drama|Horror|Romance : ['Comedy|Drama|Romance']
# Documentary : ['Documentary']
# Comedy|Drama|Romance : ['Comedy|Drama|Horror|Romance']
# Comedy|Drama|Music : ['Comedy|Drama']
# Drama : ['Drama']
# Drama|Romance : ['Drama|Romance|War']
# Comedy|Romance : ['Comedy|Drama|Romance']
# Documentary : ['Documentary']
# Drama : ['Drama']
# Crime|Drama|Thriller : ['Crime|Drama|Thriller']
# Drama : ['Drama']
# Comedy|Drama|Romance : ['Comedy|Romance']
# Drama|Music|Romance : ['Drama|Romance']
# Comedy : ['Comedy']
# Documentary : ['Documentary']
# Horror : ['Horror']
# Documentary : ['Documentary']
# Documentary : ['Documentary']
# Documentary : ['Documentary']
# Drama : ['Drama']
# Documentary|War : ['Documentary']
# Comedy|Drama : ['Comedy|Drama|Music']
# Romance : ['Romance']
# Comedy : ['Comedy']
# Comedy : ['Comedy']
# Drama|Horror|Mystery : ['Horror|Mystery']
# Drama : ['Drama']
# Comedy : ['Comedy']
# Drama|Sport : ['Drama|Sport']
# Crime|Drama : ['Crime|Drama']
# Comedy : ['Comedy']
# Comedy|Drama : ['Comedy|Drama']
# Family : ['Family']
# Documentary : ['Documentary|War']
# Crime|Drama : ['Crime|Drama']
# Biography|Documentary|Music : ['Biography|Documentary|Music']
# Documentary : ['Documentary']
# Comedy|Romance : ['Comedy|Drama|Romance']
# Biography|Comedy|Romance : ['Biography|Drama|Romance']
# Comedy : ['Comedy']
# Comedy|Drama : ['Comedy|Drama']
# Drama : ['Drama']
# Comedy : ['Comedy']
# Drama|Horror|Mystery : ['Drama|Horror|Mystery']
# Comedy|Drama|Romance : ['Comedy|Romance']
# Crime|Drama|Thriller : ['Crime|Drama|Thriller']
# Comedy|Drama|Romance : ['Comedy|Drama|Romance']
# Comedy|Drama|Romance : ['Comedy|Drama|Romance']
# Crime|Drama|Horror : ['Drama|Horror', 'drama suspense horror crime']
# Comedy|Drama : ['Comedy|Drama']
# Documentary : ['Documentary']
# Documentary : ['Documentary']
# Biography|Documentary : ['Biography|Documentary|Music']
# Drama : ['Drama']
# Comedy : ['Comedy']
# Drama : ['Drama']
# Comedy|Romance : ['Comedy|Drama|Romance']
# Horror : ['Horror']
# Drama : ['Drama']
# Western : ['Western']
# Comedy : ['Comedy']
# Horror : ['Horror']
# Comedy|Crime|Drama : ['Comedy|Drama']
# Comedy : ['Comedy']
# Comedy|Drama : ['Comedy|Crime|Drama']
# Comedy|Drama : ['Comedy|Drama']
# Action|Crime|Drama|Thriller : ['Crime|Drama|Thriller']
# Action|Crime|Thriller : ['Action|Crime|Drama|Thriller']
# Comedy|Drama : ['Comedy|Drama']
# Comedy|Romance : ['Comedy|Romance']
# Drama : ['Drama']
# Comedy|Drama|Romance : ['Comedy|Romance']
# Drama : ['Drama']
# Romance : ['Romance']
# Drama|Music|Romance : ['Drama|Music|Romance']
# Drama : ['Drama']
# Horror : ['Horror']
# Drama : ['Drama']
# Crime|Drama : ['Crime|Drama']
# Crime|Drama : ['Crime|Drama']
# Comedy|Drama : ['Comedy|Drama']
# Comedy|Drama : ['Comedy|Drama']
# Comedy|Drama|Romance : ['Comedy|Drama|Romance']
# Documentary : ['Documentary']

# %% [markdown]
# Agora que terminamos de aplicar a nossa função e encontrar a similaridade entre os nossos dados, vamos verificar quantos valores únicos nosso dataset possui agora.

# %%
print(df["Genre"].unique().shape[0])
# Out:
# 994

# %%
df.head(20)
# Out:
#                                                 Title  ...                                               Plot
# 0                              Kansas Saloon Smashers  ...  A bartender is working at a saloon, serving dr...
# 1                       Love by the Light of the Moon  ...  The moon, painted with a smiling face hangs ov...
# 2                             The Martyred Presidents  ...  The film, just over a minute long, is composed...
# 3                    Terrible Teddy, the Grizzly King  ...  Lasting just 61 seconds and consisting of two ...
# 4                              Jack and the Beanstalk  ...  The earliest known adaptation of the classic f...
# 5                                 Alice in Wonderland  ...  Alice follows a large white rabbit down a "Rab...
# 6                             The Great Train Robbery  ...  The film opens with two bandits breaking into ...
# 7                                     The Suburbanite  ...  The film is about a family who move to the sub...
# 8                            The Little Train Robbery  ...  The opening scene shows the interior of the ro...
# 9                          The Night Before Christmas  ...  Scenes are introduced using lines of the poem....
# 10                           Dream of a Rarebit Fiend  ...  The Rarebit Fiend gorges on Welsh rarebit at a...
# 11  From Leadville to Aspen: A Hold-Up in the Rockies  ...  The film features a train traveling through th...
# 12                                Kathleen Mavourneen  ...  Irish villager Kathleen is a tenant of Captain...
# 13                                       Daniel Boone  ...  Boone's daughter befriends an Indian maiden as...
# 14                    How Brown Saw the Baseball Game  ...  Before heading out to a baseball game at a nea...
# 15                                       Laughing Gas  ...  The plot is that of a black woman going to the...
# 16                           The Adventures of Dollie  ...  On a beautiful summer day a father and mother ...
# 17                                    The Black Viper  ...  A thug accosts a girl as she leaves her workpl...
# 18                             A Calamitous Elopement  ...  A young couple decides to elope after being ca...
# 19                               The Call of the Wild  ...  A white girl (Florence Lawrence) rejects a pro...
#
# [20 rows x 3 columns]

# %% [markdown]
# Bem, podemos observar agora que tivemos uma redução consideravel no número de valores únicos em nosso dataset.

# %% [markdown]
# Na verdade muitos desses valores significavam a mesma coisa, porém estavam escritos de várias formas diferentes. Ainda possuimos alguns valores incorretos, mais a sua grande maioria foi tratada.
